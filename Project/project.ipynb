# %% [markdown]
# # Data Load
#
# This section loads the required data into the notebook for analysis and processing.
#
# - Import necessary libraries
# - Read the source data
# - Validate the loaded dataset
# - Prepare the data for downstream steps

# %%
# import 
import pandas as pd

# %%
df = pd.read_csv('Dataset/modified/DSE_Data_Manupulation_with_Sector.csv')
df.head()
# Out:
#    Row_Number Trading_Code       Sector        Date  Open  High   Low  Close  \
# 0           0         SIBL         Bank  2025-04-08   9.9  10.0   9.8    9.9
# 1           1   MEGHNALIFE    Insurance  2025-04-08  54.5  56.6  54.1   56.1
# 2           2         BPML   PaperPrint  2025-04-08  41.1  41.7  40.0   40.2
# 3           3   CROWNCEMNT          NaN  2025-04-08  47.9  50.9  47.5   50.0
# 4           4      ATCSLGF  MutualFunds  2025-04-08   0.0   0.0   0.0    7.5
#
#      Volume
# 0  359773.0
# 1  610711.0
# 2  482031.0
# 3  104860.0
# 4       0.0

# %%
print(df.info())
print("\nMissing values per column:")
display(df.isna().sum())

print("\nDuplicate rows:", df.duplicated().sum())
print("Duplicate timestamps:", df["Date"].duplicated().sum())

print("\nDescriptive statistics:")
display(df.describe().T)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1455180 entries, 0 to 1455179
# Data columns (total 9 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Row_Number    1455180 non-null  int64
#  1   Trading_Code  1455180 non-null  object
#  2   Sector        1240873 non-null  object
#  3   Date          1455180 non-null  object
#  4   Open          1455180 non-null  float64
#  5   High          1455180 non-null  float64
#  6   Low           1455180 non-null  float64
#  7   Close         1455180 non-null  float64
#  8   Volume        1455180 non-null  float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 99.9+ MB
# None
#
# Missing values per column:
# Row_Number           0
# Trading_Code         0
# Sector          214307
# Date                 0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Volume               0
# dtype: int64
# Duplicate rows: 0
# ...
